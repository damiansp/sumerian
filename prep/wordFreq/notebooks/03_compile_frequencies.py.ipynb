# %% [markdown]
# See notes <a href="https://etcsl.orinst.ox.ac.uk/edition2/encodingdisplay.php#critical">here</a> about transliteration conventions.

# %%
from collections import Counter
import json
import os
import re

import pandas as pd

# %%
DATA = '../../../data/corpus_clean'

# %%
infiles = [f for f in os.listdir(DATA) if f.endswith('.txt')]
print(len(infiles))
infiles[:3]
# Out:
# 347
# ['An_excerpt_from_a_hymn_to_Nanna.txt',
#  'Letter_from_Aradngu_to_Shulgi_about_attentive_citizens.txt',
#  'A_hymn_to_Ur-Namma_(Ur-Namma_I).txt']

# %%
word_counts = Counter()
testc = Counter()

# %%
def remove_digit_sequences(text):
    # Use regex to find sequences of digits surrounded by non-alphanumeric characters
    clean_text = re.sub(r'(?<!\w)\d+(?!\w)', '', text)
    return clean_text.strip('-')

# %%
remove_digit_sequences('2-0-26')
# Out:
# ''

# %%
def get_ngrams(word, mx=5):
    word = remove_digit_sequences(word)
    grams = {}
    parts = word.split('-')
    if not parts or len(parts) == 1 and not parts[0]: 
        return grams
    try:
        while parts[0][0] in '0123456789':
            parts = parts[1:]
        if not parts or len(parts) == 1 and not parts[0]: 
            return grams
    except IndexError:
        return grams
    except:
        print(parts)
        raise
    for start in range(len(parts)):
        for end in range(start + 1, min(len(parts), mx) + 1):
            gram = '-'.join(parts[start:end]).strip('-')
            gram = re.sub(r'\-+', '-', gram)
            grams[gram] = grams.get(gram, 0) + 1
    return grams

# %%
get_ngrams('107A-try-me')
# Out:
# {'try': 1, 'try-me': 1, 'me': 1}

# %%
line = '521A- d-a-nun-na'
for word in line.split('-'):
    print(word)
    print(get_ngrams(word))
    print()
# Out:
# 521A
# {}
#
#  d
# {' d': 1}
#
# a
# {'a': 1}
#
# nun
# {'nun': 1}
#
# na
# {'na': 1}

# %%
test_grams = get_ngrams('-a-li-ba-ba-zoom')
testc.update(test_grams)
testc
# Out:
# Counter({'ba': 2,
#          'a': 1,
#          'a-li': 1,
#          'a-li-ba': 1,
#          'a-li-ba-ba': 1,
#          'a-li-ba-ba-zoom': 1,
#          'li': 1,
#          'li-ba': 1,
#          'li-ba-ba': 1,
#          'li-ba-ba-zoom': 1,
#          'ba-ba': 1,
#          'ba-ba-zoom': 1,
#          'ba-zoom': 1,
#          'zoom': 1})

# %%
testc.update(test_grams)
testc
# Out:
# Counter({'ba': 4,
#          'a': 2,
#          'a-li': 2,
#          'a-li-ba': 2,
#          'a-li-ba-ba': 2,
#          'a-li-ba-ba-zoom': 2,
#          'li': 2,
#          'li-ba': 2,
#          'li-ba-ba': 2,
#          'li-ba-ba-zoom': 2,
#          'ba-ba': 2,
#          'ba-ba-zoom': 2,
#          'ba-zoom': 2,
#          'zoom': 2})

# %%
for f in infiles:
    print('Parsing file:', f)
    with open(f'{DATA}/{f}', 'r') as inf:
        for line in inf:
            line = line.replace('[...]', '').strip()
            line = re.sub(r'\.', '-', line)
            line = re.sub(r'[^a-zA-Z0-9\- ]', '', line).strip()
            line = line.replace('X', '').strip()
            line = re.sub(r' +', ' ', line)
            line = re.sub(r'\-+', '-', line)
            if (line.lower().startswith('unknown') 
                    or line.lower().startswith('segment')
                    or not line):
                continue
            try:
                for word in line.split():
                    ngrams = get_ngrams(word)
                    word_counts.update(ngrams)
            except:
                print('ERROR FOR:', line)
    print()
# Out:
# Parsing file: An_excerpt_from_a_hymn_to_Nanna.txt
#
# Parsing file: Letter_from_Aradngu_to_Shulgi_about_attentive_citizens.txt
#
# Parsing file: A_hymn_to_Ur-Namma_(Ur-Namma_I).txt
#
# Parsing file: An_adab_to_Utu_for_Shulgi_(Shulgi_Q).txt
#
# Parsing file: The_farmer's_instructions.txt
#
# Parsing file: The_shumunda_grass.txt
#
# Parsing file: A_hymn_to_Nanna_(Nanna_G).txt
#
# Parsing file: The_exploits_of_Ninurta.txt
#
# Parsing file: A_hymn_to_Numushda_for_Sîn-iqisham_(Sîn-iqisham_A).txt
#
# Parsing file: A_balbale_to_Nanna_(Nanna_D).txt
#
# Parsing file: The_message_of_Lu-dingira_to_his_mother.txt
#
# Parsing file: A_song_of_Shulgi.txt
#
# Parsing file: Letter_to_Shulgi_about_bandits_and_brigands.txt
#
# Parsing file: A_tigi_to_Inana_(Inana_E).txt
#
# Parsing file: The_return_of_Ninurta_to_Nibru.txt
#
# Parsing file: Inana_and_Ebih.txt
#
# Parsing file: The_lament_for_Eridug.txt
#
# Parsing file: The_home_of_the_fish.txt
#
# Parsing file: An_adab_to_Nuska_for_Ishme-Dagan_(Ishme-Dagan_Q).txt
#
# Parsing file: The_exaltation_of_Inana_(Inana_B).txt
#
# Parsing file: Letter_from_Sharrum-bani_to_Shu-Suen_about_keeping_the_Martu_at_bay.txt
#
# Parsing file: A_balbale_to_Inana_as_Nanaya_(Inana_H).txt
#
# Parsing file: A_song_of_Inana_for_Ishme-Dagan_(Ishme-Dagan_J).txt
#
# Parsing file: A_prayer_for_Samsu-iluna_(Samsu-iluna_C).txt
#
# Parsing file: Letter_from_Shulgi_to_Puzur-Shulgi_about_waterways.txt
#
# Parsing file: OB_catalogue_from_Nibru_(N6).txt
#
# Parsing file: How_grain_came_to_Sumer.txt
#
# Parsing file: The_advice_of_a_supervisor_to_a_younger_scribe_(E-dubba_C).txt
#
# Parsing file: A_hymn_to_Sadarnuna_(Sadarnuna_A).txt
#
# Parsing file: Lugalbanda.txt
#
# Parsing file: The_history_of_the_Tummal.txt
#
# Parsing file: Letter_from_Aradngu_to_Shulgi_about_Aba-indasa's_missing_troops.txt
#
# Parsing file: A_shir-namshub_to_Utu_(Utu_E).txt
#
# Parsing file: A_hymn_to_Nanna_for_Gungunum_(Gungunum_B).txt
#
# Parsing file: A_diatribe_against_Engar-dug_(Diatribe_B).txt
#
# Parsing file: A_shirnamshub_to_Inana_(Dumuzid-Inana_M).txt
#
# Parsing file: The_poem_of_early_rulers.txt
#
# Parsing file: Letter_from_Shulgi_(?)_to_Aradju_about_troops.txt
#
# Parsing file: A_hymn_to_Hendursanga_(Hendursanga_A).txt
#
# Parsing file: Excerpt_of_a_royal_praise_poem_(?).txt
#
# Parsing file: Pabilsang's_journey_to_Nibru.txt
#
# Parsing file: Letter_from_Shulgi_to_Aradngu_about_Apillasha.txt
#
# Parsing file: The_temple_hymns.txt
#
# Parsing file: A_tigi_to_Nergal_(Nergal_C).txt
#
# Parsing file: Samsu-iluna_and_Inana_(Samsu-iluna_A).txt
#
# Parsing file: Letter_from_Ibbi-Suen_to_Ishbi-Erra_about_his_bad_conduct.txt
#
# Parsing file: A_balbale_to_Shara_(Shara_A).txt
#
# Parsing file: A_tigi_to_Nanaya_for_Ishbi-Erra_(Ishbi-Erra_C).txt
#
# Parsing file: Letter_from_Sîn-iddinam_to_the_god_Utu_about_the_distress_of_Larsa.txt
#
# Parsing file: A_tigi_to_Inana_and_Dumuzid_(Dumuzid-Inana_H).txt
#
# Parsing file: A_song_of_Inana_and_Dumuzid_(Dumuzid-Inana_C1).txt
#
# Parsing file: A_Hymn_to_Nanshe_(Nanshe_A).txt
#
# Parsing file: The_song_of_the_hoe.txt
#
# Parsing file: The_lament_for_Nibru.txt
#
# Parsing file: OB_catalogue_at_Andrews_University_(B4).txt
#
# Parsing file: Amar-Suena_and_Enki's_Temple_(Amar-Suena_A).txt
#
# Parsing file: A_prayer_for_Samsu-iluna_(Samsu-iluna_B).txt
#
# Parsing file: Letter_from_Shulgi_to_Aradngu_about_Aba-indasa.txt
#
# Parsing file: An_adab_of_An_for_Ur-Ninurta_(Ur-Ninurta_E).txt
#
# Parsing file: The_Sargon_legend.txt
#
# Parsing file: OB_catalogue_possibly_from_Zimbir_(B1).txt
#
# Parsing file: Inana_and_Enki.txt
#
# Parsing file: Poem_of_Utu-hejal_--_a_composite_transliteration.txt
#
# Parsing file: A_hymn_to_Nininsina_for_Ishbi-Erra_(Ishbi-Erra_D).txt
#
# Parsing file: An_adab_to_Enlil_for_Shulgi_(Shulgi_G).txt
#
# Parsing file: A_balbale_to_Inana_and_Dumuzid_(Dumuzid-Inana_D).txt
#
# Parsing file: A_man_and_his_god_.txt
#
# Parsing file: An_adab_to_An_for_Shu-Suen_(Shu-Suen_E).txt
#
# Parsing file: A_tigi_to_Suen_for_Ibbi-Suen_(Ibbi-Suen_A).txt
#
# Parsing file: Letter_from_Gudea_to_his_god_imploring_support.txt
#
# Parsing file: A_praise_poem_of_Ishme-Dagan_(Ishme-Dagan_AA).txt
#
# Parsing file: Lullaby_for_a_son_of_Shulgi_(Shulgi_N).txt
#
# Parsing file: A_shir-gida_to_Nuska_(Nuska_B).txt
#
# Parsing file: Sîn-iddinam_and_Ishkur_(Sîn-iddinam_E).txt
#
# Parsing file: An_adab_to_Dagan_(?)_for_Ishme-Dagan_(Ishme-Dagan_U).txt
#
# Parsing file: Inana_and_Shu-kale-tuda.txt
#
# Parsing file: A_tigi_to_Enlil_for_Ur-Namma_(Ur-Namma_B).txt
#
# Parsing file: OB_catalogue_from_Urim_(U1).txt
#
# Parsing file: The_cursing_of_Agade.txt
#
# Parsing file: A_shir-gida_to_Nininsina_(Nininsina_A).txt
#
# Parsing file: A_hymn_to_Nanna_(Nanna_M).txt
#
# Parsing file: A_prayer_for_Samsu-iluna_(Samsu-iluna_E).txt
#
# Parsing file: A_love_song_of_Shu-Suen_(Shu-Suen_A).txt
#
# Parsing file: Ur_III_catalogue_at_Yale_(Y1).txt
#
# Parsing file: A_hymn_to_Shul-pa-ed_(Shul-pa-ed_A).txt
#
# Parsing file: A_hymn_to_Nininsina_(Nininsina_D).txt
#
# Parsing file: A_balbale_to_Inana_and_Dumuzid_(Dumuzid-Inana_O).txt
#
# Parsing file: A_song_of_Inana_and_Dumuzid_(Dumuzid-Inana_F1).txt
#
# Parsing file: Letter_from_Shulgi_to_Puzur-Shulgi_about_work_on_the_fortress_Igi-hursanga.txt
#
# Parsing file: Letter_from_Aba-indasa_to_Shulgi_about_his_neglect.txt
#
# Parsing file: Hymn_to_the_E-kur.txt
#
# Parsing file: A_hymn_to_Inana.txt
#
# Parsing file: A_praise_poem_of_Ishme-Dagan.txt
#
# Parsing file: A_praise_poem_of_Shulgi_(Shulgi_A).txt
#
# Parsing file: Letter_from_Ur-dun_to_Shulgi_about_the_purchase_of_cedar_resin.txt
#
# Parsing file: Enlil_and_Sud.txt
#
# Parsing file: An_adab_for_Shu-ilishu_(Shu-ilishu_C).txt
#
# Parsing file: A_shir-namshub_to_Inana_(Inana_I).txt
#
# Parsing file: A_praise_poem_of_Abi-Eshuh_(Abi-Eshuh_A).txt
#
# Parsing file: An_adab_to_Nanna_(Nanna_H).txt
#
# Parsing file: A_praise_poem_of_Hammu-rabi_(Hammu-rabi_A).txt
#
# Parsing file: An_adab_to_Enlil_for_Ishme-Dagan_(Ishme-Dagan_H).txt
#
# Parsing file: A_fragment_of_a_hymn_to_Nanna.txt
#
# Parsing file: Letter_from_Nanna-kiang_to_Lipit-Eshtar_about_Gungunum's_troops.txt
#
# Parsing file: A_balbale_to_Ningishzida_(Ningishzida_A).txt
#
# Parsing file: A_tigi_to_Ninurta_for_Shulgi_(Shulgi_T).txt
#
# Parsing file: An_ululumama_to_Nanna_(Nanna_J).txt
#
# Parsing file: A_song_of_Inana_and_Dumuzid_(Dumuzid-Inana_D1).txt
#
# Parsing file: A_balbale_to_Nanna_(Nanna_B).txt
#
# Parsing file: A_shir-namshub_to_Ninurta_(Ninurta_G).txt
#
# Parsing file: A_praise_poem_of_Shulgi_(Shulgi_X).txt
#
# Parsing file: A_song_of_Inana_and_Dumuzi_(Dumuzi-Inana_W).txt
#
# Parsing file: A_balbale_to_Inana_and_Dumuzid_(Dumuzid-Inana_C).txt
#
# Parsing file: Self-praise_of_Ishme-Dagan_(Ishme-Dagan_A).txt
#
# Parsing file: A_shir-namgala_to_Ninisina_for_Lipit-Eshtar_(Lipit-Eshtar_E).txt
#
# Parsing file: Letter_from_Puzur-Shulgi_to_Ibbi-Suen_about_Ishbi-Erra's_claim_on_Isin.txt
#
# Parsing file: An_adab_to_Enki_for_Ishme-Dagan_(Ishme-Dagan_D).txt
#
# Parsing file: An_adab_to_Nanna_for_Ishme-Dagan_(Ishme-Dagan_M).txt
#
# Parsing file: A_tigi_to_Nanna_(Nanna_I).txt
#
# Parsing file: A_praise_poem_of_Sîn-iddinam_(Sîn-iddinam_A).txt
#
# Parsing file: Enki_and_Ninmah.txt
#
# Parsing file: The_Kesh_temple_hymn.txt
#
# Parsing file: Ninurta_and_the_turtle.txt
#
# Parsing file: A_kungar_to_Inana_and_Dumuzid_(Dumuzid-Inana_I).txt
#
# Parsing file: A_shir-namgala_to_Meshlamta-eda_and_Lugal-era_for_Ibbi-Suen_(Ibbi-Suen_B).txt
#
# Parsing file: OB_catalogue_from_Nibru,_at_Philadelphia_(N2).txt
#
# Parsing file: Letter_from_Aradngu_to_Shulgi_about_the_fortress_Igi-hursanga.txt
#
# Parsing file: A_shir-gida_to_Martu_(Martu_A).txt
#
# Parsing file: A_praise_poem_of_Shulgi_(Shulgi_L).txt
#
# Parsing file: The_lament_for_Sumer_and_Urim.txt
#
# Parsing file: A_balbale_to_Inana_and_Dumuzid_(Dumuzid-Inana_B).txt
#
# Parsing file: An_adab_(?)_to_Ninurta_(?)_for_Ishme-Dagan_(Ishme-Dagan_P).txt
#
# Parsing file: A_prayer_for_Rim-Sin_(Rim-Sin_E).txt
#
# Parsing file: A_hymn_to_Marduk_for_a_king.txt
#
# Parsing file: A_praise_poem_of_Shulgi_(Shulgi_Y).txt
#
# Parsing file: A_song_of_Inana_and_Dumuzid_(Dumuzid-Inana_Z).txt
#
# Parsing file: A_balbale_to_Ninazu_(Ninazu_A).txt
#
# Parsing file: Enmerkar_and_En-suhgir-ana.txt
#
# Parsing file: A_balbale_to_Nanna_(Nanna_C).txt
#
# Parsing file: A_hymn_to_Ishkur_for_Ur-Ninurta_(Ur-Ninurta_F)_.txt
#
# Parsing file: An_adab_to_Nanna_for_Gungunum_(Gungunum_A).txt
#
# Parsing file: A_hymn_to_Nungal.txt
#
# Parsing file: Enlil_and_Nam-zid-tara.txt
#
# Parsing file: A_hymn_to_Enlil_for_Samsu-iluna_(Samsu-iluna_H).txt
#
# Parsing file: A_balbale_to_Ningishzida_(Ningsihzida_B).txt
#
# Parsing file: Letter_from_Puzur-Shulgi_to_Shulgi_about_the_advance_of_the_enem.txt
#
# Parsing file: An_adab_to_Bau_for_Ishme-Dagan_(Ishme-Dagan_B).txt
#
# Parsing file: A_balbale_to_Enki_for_Ishme-Dagan_(Ishme-Dagan_E).txt
#
# Parsing file: A_song_of_Inana_and_Dumuzid_(Dumuzid-Inana_B1).txt
#
# Parsing file: Nanshe_and_the_birds_(Nanshe_C).txt
#
# Parsing file: A_hymn_to_Ninurta_(Ninurta_C).txt
#
# Parsing file: An_adab_of_Inana_for_Ur-Ninurta_(Ur-Ninurta_D).txt
#
# Parsing file: Letter_from_Ur-saga_to_a_king_fearing_the_loss_of_his_father's_household.txt
#
# Parsing file: An_elegy_on_the_death_of_Nawirtum_(Elegy_2).txt
#
# Parsing file: A_balbale_to_Nanshe_(Nanshe_B).txt
#
# Parsing file: A_song_of_Inana_and_Dumuzid_(Dumuzid-Inana_V).txt
#
# Parsing file: Letter_from_Ibbi-Suen_to_Puzur-Shulgi_hoping_for_Ishbi-Erra's_downfall.txt
#
# Parsing file: An_adab_of_Inana_for_Rim-Sin_(Rim-Sin_H).txt
#
# Parsing file: A_shir-namshub_to_Nanna_for_Ur-Namma_(Ur-Namma_E).txt
#
# Parsing file: A_prayer_for_Samsu-iluna_(Samsu-iluna_D).txt
#
# Parsing file: A_prayer_(?)_for_Rim-Sin_(Rim-Sin_A).txt
#
# Parsing file: A_tigi_to_Nintud-Aruru_(Nintud_A).txt
#
# Parsing file: A_hymn_to_Martu_(Martu_B).txt
#
# Parsing file: A_hymn_to_Inana_(Inana_F).txt
#
# Parsing file: Inana_and_Lipit-Eshtar_(Lipit-Eshtar_H).txt
#
# Parsing file: A_hymn_to_Ningishzida_(Ningishzida_C).txt
#
# Parsing file: A_song_of_Ningishzida_(Ningishzida_D).txt
# Parsing file: A_hymn_to_Suen_for_Ibbi-Suen.txt
#
# Parsing file: Shulgi_and_Ninlil's_Barge_(Shulgi_R).txt
#
# Parsing file: A_balbale_of_Inana_(Inana_A).txt
#
# Parsing file: Enki_and_Ninhursanga.txt
#
# Parsing file: A_praise_poem_of_Hammu-rabi_(Hammu-rabi_C).txt
#
# Parsing file: A_hymn_to_Asarluhi_(Asarluhi_XA).txt
#
# Parsing file: Ishbi-Erra_and_Kindattu_(Ishbi-Erra_B).txt
#
# medical_treatment.txtfrom_Nanna-manshum_to_the_goddess_Ninisina_about_his_unsuccessful
#
# Parsing file: A_praise_poem_of_Shulgi_(Shulgi_C).txt
#
# Parsing file: The_heron_and_the_turtle.txt
#
# Parsing file: Enki's_journey_to_Nibru.txt
#
# Parsing file: A_shir-namshub_to_Nininsina_(Nininsina_B).txt
#
# Parsing file: A_shir-namgala_to_Nanna_(Nanna_L).txt
#
# Parsing file: A_praise_poem_of_Shulgi_(Shulgi_V).txt
#
# Parsing file: An_adab_to_Enlil_for_Bur-Suen_(Bur-Suen_B).txt
#
# Parsing file: OB_catalogue_at_Yale_(Y2).txt
#
# Parsing file: Gilgamesh_and_Huwawa,_Version_B.txt
#
# Parsing file: A_shir-namshub_to_Nanna_for_Ur-Namma_(Ur-Namma_F).txt
#
# Parsing file: A_praise_poem_of_Enlil-bani_(Enlil-bani_A).txt
#
# Parsing file: A_prayer_for_Samsu-iluna_(Samsu-iluna_G).txt
#
# Parsing file: A_hymn_to_Nanna_(Nanna_O).txt
#
# Parsing file: Inana_and_Iddin-Dagan_(Iddin-Dagan_A).txt
#
# Parsing file: A_song_to_Ninimma_(Ninimma_A).txt
#
# Parsing file: Gilgamesh,_Enkidu_and_the_nether_world.txt
#
# Parsing file: Letter_from_Lipit-Eshtar_to_Nanna-kiang_about_driving_away_the_enemy_.txt
#
# Parsing file: OB_catalogue_from_Urim_(U3).txt
#
# Parsing file: A_praise_poem_of_Anam.txt
#
# Parsing file: A_shirgida_to_Nuska_(Nuska_A).txt
#
# Parsing file: A_shir-namshub_to_Inana_(Inana_G).txt
#
# Parsing file: Dedication_of_a_statue_(of_Shulgi?)_by_Ishme-Dagan_(Ishme-Dagan_S).txt
#
# Parsing file: A_praise_poem_of_Lipit-Eshtar_(Lipit-Eshtar_A).txt
#
# Parsing file: Letter_from_X_to_the_god_Nanna.txt
#
# Parsing file: A_praise_poem_of_Shulgi_(Shulgi_O).txt
#
# Parsing file: A_song_of_Inana_and_Dumuzid_(Dumuzid-Inana_L).txt
#
# Parsing file: A_shir-gida_(?)_of_Ninshubur_(Ninshubur_A).txt
#
# Parsing file: Hymn_to_Inana_as_Ninegala_(Inana_D).txt
#
# Parsing file: A_namerima_(?)_for_Iddin-Dagan_(Iddin-Dagan_D).txt
#
# Parsing file: A_balbale_to_Inana_and_Dumuzid_(Dumuzid-Inana_A).txt
#
# Parsing file: An_adab_to_Ninurta_for_Lipit-Eshtar_(Lipit-Eshtar_D).txt
#
# Parsing file: A_hymn_to_Shu-Suen.txt
#
# Parsing file: Inana's_descent_to_the_nether_world.txt
#
# Parsing file: A_praise_poem_of_Ur-Namma_(Ur-Namma_C).txt
#
# Parsing file: A_song_of_Inana_and_Dumuzid_(Dumuzid-Inana_Y).txt
#
# Parsing file: Letter_from_Aradngu_to_Shulgi_about_Apillasha.txt
#
# Parsing file: A_prayer_for_Hammu-rabi_(Hammu-rabi_E).txt
#
# Parsing file: Gilgamesh_and_Huwawa,_Version_A.txt
#
# Parsing file: Excerpt_from_a_praise_poem_of_Rim-Sîn.txt
#
# Parsing file: The_building_of_Ningirsu´s_temple.txt
#
# Parsing file: A_hymn_to_Bau's_Beneficent_Protective_Goddess_(Bau_A).txt
#
# Parsing file: An_adab_to_Ningublaga_for_Iddin-Dagan_(Iddin-Dagan_C).txt
#
# Parsing file: The_debate_between_Bird_and_Fish.txt
#
# Parsing file: Gilgamesh_and_the_Bull_of_Heaven.txt
#
# Parsing file: Praise_of_Lipit-Eshtar_(Lipit-Eshtar_B).txt
#
# Parsing file: A_balbale_to_Enlil_for_Ur-Namma_(Ur-Namma_G).txt
#
# Parsing file: Gilgamesh_and_Aga.txt
#
# Parsing file: Enmerkar_and_the_lord_of_Aratta.txt
#
# Parsing file: A_balbale_to_Nanna_(Nanna_A).txt
#
# Parsing file: The_debate_between_Winter_and_Summer.txt
#
# Parsing file: A_prayer_for_Hammu-rabi_(Hammu-rabi_D).txt
#
# Parsing file: Enki_and_the_world_order.txt
#
# Parsing file: A_prayer_for_Rim-Sin_(Rim-Sin_G).txt
#
# Parsing file: A_hymn_to_Nisaba_(Nisaba_A).txt
#
# Parsing file: A_prayer_for_Rim-Sin_entering_the_gate_(Rim-Sin_D).txt
#
# Parsing file: Ur_III_catalogue_from_Nibru_(N1).txt
#
# Parsing file: A_hymn_to_Nergal_(Nergal_B).txt
#
# Parsing file: A_shir-gida_to_Ninurta_(Ninurta_A).txt
#
# Parsing file: The_song_of_the_ploughing_oxen.txt
#
# Parsing file: An_elegy_on_the_death_of_Nannaya_(Elegy_1).txt
#
# Parsing file: An_adab_to_Bau_for_Luma.txt
#
# Parsing file: Letter_from_Ishbi-Erra_to_Ibbi-Suen_about_the_purchase_of_grain.txt
#
# Parsing file: A_hymn_to_Enlil_for_Samsu-iluna_(Samsu-iluna_F).txt
#
# Parsing file: A_hymn_to_Nergal_for_Shulgi_(Shulgi_U).txt
#
# Parsing file: A_hymn_to_Inana_for_Hammu-rabi_(Hammu-rabi_F).txt
#
# Parsing file: OB_Catalogue_from_Urim_(U2).txt
#
# Parsing file: Self-praise_of_Shulgi_(Shulgi_D).txt
#
# Parsing file: A_hymn_to_Nanna_(Nanna_N).txt
#
# Parsing file: A_love_song_of_Shu-Suen_(Shu-Suen_B).txt
#
# Parsing file: The_song_of_the_lettuce.txt
#
# Parsing file: Inana_and_Ishme-Dagan_(Ishme-Dagan_K).txt
#
# Parsing file: A_balbale_to_Inana_and_Dumuzid.txt
#
# Parsing file: OB_catalogue_from_Nibru_(N3).txt
#
# Parsing file: A_song_of_Inana_and_Dumuzid_(Dumuzid-Inana_T).txt
#
# Parsing file: A_praise_poem_of_Shulgi_(Shulgi_W).txt
#
# Parsing file: A_hymn_to_Haia_for_Rim-Sin_(Rim-Sin_B).txt
#
# Parsing file: An_adab_(?)_to_Suen_for_Shu-Suen_(Shu-Suen_F).txt
#
# Parsing file: A_love_song_of_Shulgi_(Shulgi_Z).txt
#
# Parsing file: A_praise_poem_of_Shulgi_(Shulgi_B).txt
#
# Parsing file: The_herds_of_Nanna_(Nanna_F).txt
#
# Parsing file: Ur-Namma_the_canal-digger_(Ur-Namma_D).txt
#
# Parsing file: A_tigi_to_Bau_for_Gudea.txt
#
# Parsing file: A_praise_poem_of_Abi-Eshuh_(Abi-Eshuh_B).txt
#
# Parsing file: Nininsina_and_the_gods_(Nininsina_F).txt
#
# Parsing file: The_lament_for_Unug.txt
#
# Parsing file: A_prayer_to_An_for_Rim-Sin_(Rim-Sin_C).txt
#
# Parsing file: A_shir-namshub_to_Nisaba_(Nisaba_B).txt
#
# Parsing file: A_song_of_Inana_and_Dumuzid_(Dumuzid-Inana_J).txt
#
# Parsing file: The_debate_between_Sheep_and_Grain.txt
#
# Parsing file: An_adab_(?)_to_Ninurta_for_Ishme-Dagan_(Ishme-Dagan_O).txt
#
# Parsing file: A_balbale_to_Inana_and_Dumuzid_(Dumuzid-Inana_G).txt
#
# Parsing file: An_adab_to_Ninurta_for_Bur-Suen_(Bur-Suen_A).txt
#
# Parsing file: A_shir-namshub_to_Nanna_(Nanna_K).txt
#
# Parsing file: A_tigi_(?)_to_Ninurta_for_Shu-Suen_(Shu-Suen_D).txt
#
# Parsing file: Rulers_of_Lagash.txt
#
# Parsing file: A_hymn_to_Nanna_(Nanna_E).txt
#
# Parsing file: The_debate_between_the_Hoe_and_the_Plough.txt
#
# Parsing file: Enlil_and_Ninlil.txt
#
# Parsing file: A_hymn_to_Nanna.txt
#
# Parsing file: The_debate_between_Silver_and_Copper.txt
#
# Parsing file: A_hymn_to_Nibru_and_Ishme-Dagan_(Ishme-Dagan_W).txt
#
# Parsing file: Letter_from_Shulgi_to_Ishbi-Erra_about_the_purchase_of_grain.txt
#
# Parsing file: An_adab_of_Ninurta_for_Ur-Ninurta_(Ur-Ninurta_C).txt
#
# Parsing file: Letter_from_Shu-Suen_to_Sharrum-bani_about_digging_a_trench.txt
#
# Parsing file: A_hymn_to_Enki_for_Ishme-Dagan.txt
#
# Parsing file: The_instructions_of_Shuruppag.txt
#
# Parsing file: Nanna-Suen's_journey_to_Nibru.txt
#
# Parsing file: Nintinuga's_dog.txt
#
# Parsing file: A_balbale_(?)_to_Inana_and_Dumuzid_(Dumuzid-Inana_P).txt
#
# Parsing file: A_praise_poem_of_Shulgi.txt
#
# Parsing file: A_praise_poem_of_Shulgi_(Shulgi_E).txt
#
# Parsing file: Inana_and_Bilulu.txt
#
# Parsing file: The_dedication_of_an_axe_to_Nergal.txt
#
# Parsing file: Letter_from_Iddin-Dagan_to_Sîn-illat_about_the_troops.txt
#
# Parsing file: A_love_song_of_Cu-Suen_(Cu-Suen_C).txt
#
# Parsing file: A_praise_poem_of_Iddin-Dagan_(Iddin-Dagan_B).txt
#
# Parsing file: An_ululumama_to_Suen_for_Ibbi-Suen_(Ibbi-Suen_D).txt
#
# Parsing file: A_praise_poem_of_Shulgi_(Shulgi_P).txt
#
# Parsing file: A_hymn_to_Ninkasi.txt
#
# Parsing file: A_hymn_to_Kusu.txt
#
# Parsing file: Ishme-Dagan_and_Enlil's_Chariot_(Icme-Dagan_I).txt
#
# Parsing file: The_Sumerian_king_list.txt
#
# Parsing file: The_marriage_of_Martu.txt
#
# Parsing file: The_lament_for_Urim.txt
#
# Parsing file: A_hymn_to_Inana_(Inana_C).txt
#
# Parsing file: A_hymn_of_Inana_for_Ur-Ninurta_(Ur-Ninurta_A).txt
#
# Parsing file: A_tigi_of_Enki_for_Ur-Ninurta_(Ur-Ninurta_B).txt
#
# Parsing file: A_balbale_to_Inana_and_Dumuzid_(Dumuzid-Inana_E1).txt
#
# Parsing file: Letter_from_Sîn-illat_to_Iddin-Dagan_about_confronting_the_Martu.txt
#
# Parsing file: Dumuzid_and_Enkimdu.txt
#
# Parsing file: Enlil_in_the_E-kur_(Enlil_A).txt
#
# Parsing file: A_praise_poem_of_Ur-Namma_(Ur-Namma_H).txt
#
# Parsing file: The_debate_between_the_Date_Palm_and_the_Tamarisk.txt
#
# Parsing file: A_song_of_Inana_and_Dumuzid_(Dumuzid-Inana_R).txt
#
# Parsing file: Three_ox-drivers_from_Adab.txt
#
# Parsing file: A_hymn_to_Utu_(Utu_B).txt
#
# Parsing file: An_adab_to_Nininsina_(Nininsina_E).txt
#
# Parsing file: A_hymn_to_Ninurta.txt
#
# Parsing file: Nininsina's_journey_to_Nibru.txt
#
# Parsing file: A_shir-namshub_to_Utu_(Utu_F).txt
#
# Parsing file: A_drinking_song.txt
#
# Parsing file: OB_catalogue_from_Nippur_(N4).txt
#
# Parsing file: The_tale_of_Gudam.txt
#
# Parsing file: OB_catalogue_in_the_Louvre_(L).txt
#
# Parsing file: A_praise_poem_of_Shu-Suen_(?)_(Shu-Suen_I).txt
#
# Parsing file: A_prayer_to_Marduk_(?)_for_Hammu-rabi_(Hammu-rabi_B).txt
#
# Parsing file: Lugalbanda_in_the_mountain_cave.txt
# Parsing file: Ningishzida's_journey_to_the_nether_world.txt
#
# Parsing file: Ninurta's_journey_to_Eridug.txt
#
# Parsing file: A_tigi_to_Ninurta_(Ninurta_D).txt
#
# Parsing file: Letter_from_Kug-Nanna_to_Ninshubur.txt
#
# Parsing file: Fragment_of_royal_praise_poetry.txt
#
# Parsing file: The_death_of_Gilgamesh.txt
#
# Parsing file: A_praise_poem_of_Ishme-Dagan_(Ishme-Dagan_AC).txt
#
# Parsing file: Dumuzid_and_Geshtin-ana.txt
#
# Parsing file: An_adab_to_Ninlil_(Ninlil_A).txt
#
# Parsing file: An_adab_to_Nergal_for_Shu-ilishu_(Shu-ilishu_A).txt
#
# Parsing file: He_is_a_good_seed_of_a_dog_(Diatribe_C).txt
#
# Parsing file: An_adab_of_An_for_Lipit-Eshtar_(Lipit-Eshtar_C).txt
#
# Parsing file: The_death_of_Ur-Namma_(Ur-Namma_A).txt
#
# Parsing file: A_balbale_to_Ninurta_(Ninurta_F).txt
#
# Parsing file: A_mythic_narrative_about_Inana.txt
#
# Parsing file: An_adab_to_Suen_for_Ibbi-Suen_(Ibbi-Suen_C).txt
#
# Parsing file: A_hymn_to_Enki_for_Ishme-Dagan_(Ishme-Dagan_X).txt
#
# Parsing file: The_Flood_story.txt
#
# Parsing file: A_hymn_to_Nibru_and_Ishme-Dagan_(Ishme-Dagan_C).txt
#
# Parsing file: A_balbale_to_Inana_and_Dumuzid_(Dumuzid-Inana_F).txt
#
# Parsing file: A_prayer_for_Rim-Sîn_(Rim-Sîn_F).txt
#
# Parsing file: Letter_from_Aradngu_to_Shulgi_about_irrigation_work.txt
#
# Parsing file: A_shir-shag-hula_to_Damgalnuna.txt
#
# Parsing file: _Dumuzid's_dream.txt
#
# Parsing file: A_hymn_to_Ninshubur_(Ninshubur_B).txt

# %%
word_counts.most_common(20)
# Out:
# [('a', 11107),
#  ('mu', 8124),
#  ('d', 7687),
#  ('na', 7161),
#  ('e', 7123),
#  ('ra', 6835),
#  ('ba', 6763),
#  ('ni', 5773),
#  ('an', 5756),
#  ('en', 5472),
#  ('ga', 5257),
#  ('da', 5130),
#  ('bi', 5030),
#  ('ma', 4575),
#  ('ki', 4295),
#  ('zu', 3886),
#  ('me', 3786),
#  ('in', 3499),
#  ('nam', 3271),
#  ('la', 3011)]

# %%
with open(f'../../../data/freq/freq.json', 'w') as f:
    json.dump(dict(word_counts), f)

# %%
freq_df = pd.DataFrame(
    data=dict(word_counts).items(), columns=('ngram', 'freq')
).sort_values('ngram', ignore_index=True)
freq_df.head(20)
# Out:
#                 ngram  freq
# 0                        18
# 1            171en187     1
# 2               60ce3     1
# 3              60ci62     1
# 4          60ci62-re7     1
# 5       60ci62-re7-ec     1
# 6   60ci62-re7-ec-am3     1
# 7        60x7fenx7f62     1
# 8              9GANA2     1
# 9           9GANA2-UH     1
# 10       9GANA2-UH-ME     1
# 11     9GANA2-UH-ME-U     1
# 12               9dal     1
# 13            9dal-ha     1
# 14         9dal-ha-mu     1
# 15               9u18     1
# 16            9u18-lu     1
# 17                  A   278
# 18                A-A     1
# 19               A-AN     4

# %%
freq_df.tail()
# Out:
#                 ngram  freq
# 67481  zur-zur-ra-ke4     1
# 67482      zur-zur-re     5
# 67483  zur-zur-re-ec2     1
# 67484            zur4     1
# 67485       zur4-gin7     1

# %%
freq_df = freq_df.iloc[17:].reset_index(drop=True)
freq_df
# Out:
#                 ngram  freq
# 0                   A   278
# 1                 A-A     1
# 2                A-AN     4
# 3           A-AN-gin7     1
# 4                A-BA     1
# ...               ...   ...
# 67464  zur-zur-ra-ke4     1
# 67465      zur-zur-re     5
# 67466  zur-zur-re-ec2     1
# 67467            zur4     1
# 67468       zur4-gin7     1
#
# [67469 rows x 2 columns]

# %%
freq_df.to_csv('../../../data/freq/freq.csv', index=False)

# %%
# !head -5 ../../../data/freq/freq.csv
# Out:
# ngram,freq
# A,278
# A-A,1
# A-AN,4
# A-AN-gin7,1
