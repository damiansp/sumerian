# %% [markdown]
# Script to get the unicode and transliterations for Sumerian glyphs from Wikipedia

# %%
import json
import re

from   bs4 import BeautifulSoup
import pandas as pd
from   requests_html import HTMLSession

# %%
url = 'https://en.wikipedia.org/wiki/Cuneiform_(Unicode_block)'
session = HTMLSession()

# %%
def get_soup(url):
    session = HTMLSession()
    res = session.get(url)
    html = res.html.html
    soup = BeautifulSoup(html, 'html.parser')
    return soup

# %%
def extract_data(soup):
    table = soup.find('table', class_='wikitable')
    df = pd.read_html(str(table))[0]
    df.rename(columns={'Sign': 'Sign', 
                       'Code point': 'Unicode', 
                       '"Primary" transliteration': 'Transliteration',
                       'Borger(2003)': 'Borger_2003',
                       'Borget(1981)': 'Borger_1981', 
                       'Comments': 'Comments'},
              inplace=True)
    return df

# %%
def add_keystrokes(text):
    try:
        # tenû, gunû, šešig
        text = text.replace('ten\u00fb', '')\
            .replace('gun\u00fb', '')\
            .replace('\u0161e\u0161ig', '')\
            .replace('\u00c1', 'A')\
            .replace('\u1e2a', 'H')\
            .replace('\u0160', 'SH')
        text = re.sub(' [x/+] ', '.', text)
        pattern = ('(crossing|inverted|opposing|reversed|rotated|signs|'
                   'squared|three times|variant form|90°|\*)')
        text = re.sub(pattern, '', text)
        text = text.strip()
        text = re.sub(' ?\. ?', '.', text)
        text = text.replace(' ', '.')
        text = text.replace('..', '.')
        return text.lower()
    except AttributeError:
        print(text)
        return 'na'

# %%
soup = get_soup(url)
df = extract_data(soup)
df.loc[:, 'Keystrokes'] = df.Transliteration.apply(add_keystrokes)
df.sort_values('Keystrokes', inplace=True)
# Out:
# nan

# %%
df.head(30)
# Out:
#     Sign  Unicode  Transliteration Borger_2003 Borger(1981)      Comments  \
# 0      𒀀  U+12000                A         839          579           NaN
# 1      𒀁  U+12001            A x A         845          583         EDURU
# 2      𒀂  U+12002          A x BAD         840          580          AGAM
# 3      𒀃  U+12003    A x GAN2 tenû         NaN          NaN           NaN
# 4      𒀄  U+12004           A x ḪA         846     584; 587          ZAḪ3
# 5      𒀅  U+12005          A x IGI         844          581            ÍR
# 6      𒀆  U+12006   A x LAGAR gunû         843          582           NaN
# 7      𒀇  U+12007          A x MUŠ         842          NaN           NaN
# 8      𒀈  U+12008          A x SAG         841          585           NaN
# 9      𒀉  U+12009               A2         560          334            ID
# 10     𒀊  U+1200A               AB         223          128          ABBA
# 21     𒀕  U+12015          AB gunû         NaN          NaN  ÚNU, URUGAL2
# 11     𒀋  U+1200B         AB x AŠ2         227   128**,200a           NaN
# 12     𒀌  U+1200C   AB x DUN3 gunû         NaN          NaN           NaN
# 13     𒀍  U+1200D         AB x GAL         228          194        IRIGAL
# 14     𒀎  U+1200E   AB x GAN2 tenû         225          198           NaN
# 15     𒀏  U+1200F          AB x ḪA         236          200          NINA
# 16     𒀐  U+12010    AB x IGI gunû         229          196           NaN
# 17     𒀑  U+12011        AB x IMIN         237          NaN           NaN
# 18     𒀒  U+12012       AB x LAGAB         234          NaN           NaN
# 880    𒍰  U+12370         AB x NUN         NaN          NaN           NaN
# 19     𒀓  U+12013         AB x ŠEŠ         226         200c           NaN
# 20     𒀔  U+12014   AB x U + U + U         232          NaN          UNUG
# 22     𒀖  U+12016              AB2         672          420           LID
# 881    𒍱  U+12371          AB2 x A         NaN          NaN           NaN
# 23     𒀗  U+12017      AB2 x BALAG         676          422         LILIZ
# 24     𒀘  U+12018  AB2 x GAN2 tenû         674          423          KIR6
# 25     𒀙  U+12019    AB2 x ME + EN         679          426           NaN
# 26     𒀚  U+1201A        AB2 x ŠA3         677          424         LIBIŠ
# 27     𒀛  U+1201B       AB2 x TAK4         673         4208           NaN
#
#     Keystrokes
# 0            a
# 1          a.a
# 2        a.bad
# 3       a.gan2
# 4         a.ha
# 5        a.igi
# 6      a.lagar
# 7       a.mush
# 8        a.sag
# 9           a2
# 10          ab
# 21          ab
# 11     ab.ash2
# 12     ab.dun3
# 13      ab.gal
# 14     ab.gan2
# 15       ab.ha
# 16      ab.igi
# 17     ab.imin
# 18    ab.lagab
# 880     ab.nun
# 19    ab.shesh
# 20    ab.u.u.u
# 22         ab2
# 881      ab2.a
# 23   ab2.balag
# 24    ab2.gan2
# 25   ab2.me.en
# 26    ab2.sha3
# 27    ab2.tak4

# %%
df[['Sign', 'Unicode', 'Transliteration', 'Keystrokes']].to_csv(
    '../data/sumerian_transliteration_unicode.csv', index=False)

# %%
with open('../data/sumerianTransliterationUnicode.json', 'w') as f:
    df[
        ['Sign', 'Unicode', 'Transliteration', 'Keystrokes']
    ].to_json(f, orient='records')

# %%
def row_to_json(row):
    out = {row.Keystrokes: {'unicode': row.Unicode, 'glyph': row.Sign}}
    return out

# %%
row_to_json(df.loc[0, :])
# Out:
# {'a': {'unicode': 'U+12000', 'glyph': '𒀀'}}

# %%
def make_transliterator(df):
    out = {}
    for _, row in df.iterrows():
        entry = row_to_json(row)
        out.update(entry)
    return out

# %%
transliterator = make_transliterator(df)
with open('../data/transliterator.json', 'w') as f:
    json.dump(transliterator, f)
